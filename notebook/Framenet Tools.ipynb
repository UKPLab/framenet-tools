# %% [markdown]
# # Setup
#
# ## Download
#
# In order to be able to train the System, we need to download the required files first. The following command automatically downloads and extracts all files, but this task can also be performed manually.

# %%
# !framenet_tools download
# Out:
# 2019-08-29 09:47:31,242-INFO-Config not found, creating Config file!
# ...
#
#     Linking successful
#     /home/andre/.local/lib/python3.6/site-packages/en_core_web_sm -->
#     /home/andre/.local/lib/python3.6/site-packages/spacy/data/en_core_web_sm
#
#     You can now load the model via spacy.load('en_core_web_sm')
#
# 2019-08-29 09:47:32,776-INFO-SRLPackage: Checking for required files:
# 2019-08-29 09:47:32,777-INFO-Downloading scripts.7z
# ...

# %% [markdown]
# ## Conversion
#
# The next step is to convert the downloaded the FrameNet dataset into the required formats. Further information on formats can be found in the documentation (Section Formats).

# %%
# !framenet_tools convert
# Out:
# INFO - Marshalling test splits to semafor format
# INFO - Marshalling test splits to semafor format
# INFO - Marshalling test splits to semafor format
# INFO - Marshalling dev splits to semafor format
# INFO - Marshalling dev splits to semafor format
# INFO - Marshalling dev splits to semafor format
# INFO - Marshalling train splits to semafor format
# INFO - Marshalling train splits to semafor format
# INFO - Marshalling train splits to semafor format
# INFO - Marshalling pyfn.AnnotationSet objects to SEMEVAL XML...
# INFO - Marshalling pyfn.AnnotationSet objects to SEMEVAL XML...
# INFO - Marshalling pyfn.AnnotationSet objects to SEMEVAL XML...
# INFO - Saving output to data/experiments/xp_001/data/train.gold.xml
# INFO - Saving output to data/experiments/xp_001/data/train.gold.xml
# INFO - Saving output to data/experiments/xp_001/data/train.gold.xml
# INFO - Marshalling pyfn.AnnotationSet objects to SEMEVAL XML...
# INFO - Marshalling pyfn.AnnotationSet objects to SEMEVAL XML...
# ...

# %% [markdown]
# ## Training
#
# Now everything is prepared for training. The following command trains all stages (Note: Currently only up to Frame Identification.)

# %%
# !framenet_tools train
# Out:
# 2019-08-29 09:56:06,959-INFO-Downloading vectors from http://nlp.stanford.edu/data/glove.6B.zip
# .vector_cache/glove.6B.zip: 862MB [01:04, 13.4MB/s]
# 2019-08-29 09:57:11,254-INFO-Extracting vectors into .vector_cache
# 2019-08-29 09:57:23,699-INFO-Loading vectors from .vector_cache/glove.6B.300d.txt
# 100%|███████████████████████████████▉| 399820/400000 [00:27<00:00, 14445.02it/s]2019-08-29 09:57:51,714-INFO-Saving vectors to .vector_cache/glove.6B.300d.txt.pt
# 2019-08-29 09:57:54,817-INFO-Generating grammar tables from /usr/lib/python3.6/lib2to3/Grammar.txt
# 2019-08-29 09:57:54,837-INFO-Generating grammar tables from /usr/lib/python3.6/lib2to3/PatternGrammar.txt
#
# ...
#   2%|▋                                          | 4/262 [00:00<00:07, 34.53it/s]
# Epoch 1/50 Loss: 0.101 Acc: 0.0406 Frames: 320/16707:   2%| | 4/262 [00:00<00:07, 34.53it/s]
# Epoch 1/50 Loss: 0.101 Acc: 0.0406 Frames: 320/16707:   3%| | 9/262 [00:00<00:06, 37.57it/s]
# ...

# %% [markdown]
# ## Prediction
#
# After training has completed, the system can predict any raw textfile (and all the described formats in the documentation).
# For demonstration purposes a small file only containing two sentences was used.
#
# Taken from: The Adventures of Tom Sawyer by Mark Twain

# %%
# !framenet_tools predict --path example.txt --out_path example.json
# Out:
# 2019-08-29 10:25:21,787-INFO-Prediction successful!
